# %% [markdown]
# # Assignment  No:01
#
# Implement the Edge Aware smoothing Algorithm. Read the steps and implement in the code section below:
#
#
# **Step 1:**
# Load the necessary imports

# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# **Step 2:**
# Load the image using the opencv

# %%
img1=cv2.imread('cor.jpg')

# %% [markdown]
# **Step 3:**
# Apply the smoothing operator over the image

# %%
# I am applying guassian blur with 5x5 kernel
blur1 = cv2.GaussianBlur(img1,(5,5),0)

# %% [markdown]
# **Step 4:**
# Apply the gradient operation using the operators learned in the class to detect the edges

# %%
# I am using canny here
edges1 = cv2.Canny(img1,100,200)

# %% [markdown]
# **Step 5:**
# Loop over the smoothed image to identify the edge pixels and replace those with the none smoothed pixels.

# %%
width1, height1 = blur1.shape[:2]
result1 = blur1
for h1 in range(height1):
    for w1 in range(width1):
        if edges1[w1][h1] == 255:
            result1[w1:h1:] = img[w1:h1:]

# %% [markdown]
# **Step 6:**
# Display the Results on multiple images.

# %%
plt.figure(figsize = (15,15))
plt.subplot(2,2,1),plt.imshow(cv2.cvtColor(blur1, cv2.COLOR_BGR2RGB)),plt.title('Blur 1'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(cv2.cvtColor(result1, cv2.COLOR_BGR2RGB)),plt.title('Result 1'), plt.xticks([]), plt.yticks([])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0xd573b00>,
#  <matplotlib.image.AxesImage at 0xa335278>,
#  <matplotlib.text.Text at 0xd2f1e80>,
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))
